# %% [markdown]
# ```mermaid
# gantt
#     todayMarker off
#     dateFormat DD-MM-YYYY
#     axisFormat %d-%m
#     title Diagramme de Gantt
#     section Analyse du sujet
#         Choix des foncionnalités :26-08-2026, 17-09-2026
#         Diagrammes : 04-09-2026, 13d
#         Rédaction : 11-09-2026, 6d
#         Rédaction : 13-11-2026, 21-11-2026
#         Diaporama : 22-11-2026, 09-12-2026
#
#     section Développement de l'application
#         Classes : 18-09-2026, 1w
#         Session tests : 22-09-2026, 1w
#         BDD + DAO : 29-09-2026, 09-10-2026
#         Session tests : 06-10-2026, 1w
#         Service API : 13-10-2026, 23-10-2026
#         Session tests : 20-10-2026, 1w
#         Fonctionnalités : 27-10-2026, 13-11-2026
#         Session tests : 03-11-2026, 10d
#         Autres options : 13-11-2026, 21-11-2026
#         Tests : 17-11-2026, 21-11-2026
#
#     section Échéances
#         Dossier d'analyse : crit, 17-09-2026, 20h
#         Rapport final : crit, 21-11-2026, 20h
#         Soutenance : crit, 09-12-2026, 1d
#
# ```

# %% [markdown]
# ```mermaid
# gantt
#     dateFormat HH:mm
#     axisFormat %H:%M
#     Initial vert : vert, v1, 17:30, 2m
#     Task A : 3m
#     Task B : 8m
#     Final vert : vert, v2, 17:58, 4m
# ```
